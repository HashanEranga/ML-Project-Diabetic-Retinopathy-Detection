# %%
from scipy import misc
from PIL import Image
from skimage import exposure
from sklearn import svm

import scipy
from math import sqrt,pi
from numpy import exp
from matplotlib import pyplot as plt
import numpy as np
import glob
import matplotlib.pyplot as pltss
import cv2
from matplotlib import cm
import pandas as pd
from math import pi, sqrt
import pywt

# %%
import cv2

img=cv2.imread('C:/Users/Hashan/Desktop/DL/Diabetic Retinopathy/data/resized_train/resized_train/10_left.jpeg')

from matplotlib import pyplot as plt

plt.imshow(img)

# %%
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
#gray-result image, img-source image
#cv2.COLOR_BGR2GRAY-color conversion method
#cvtColor function is used to convert color
plt.imshow(gray,cmap='gray')

# %%
import numpy as np

kernel=np.array([[0.1,0.23,0.1],
                 [0.25,0.23,0.25],
                 [0.1,0.23,0.1]],np.float)

conv=cv2.filter2D(gray,-1,kernel)
plt.imshow(conv,cmap='gray')

# %%
print('hello')
# Out:
# hello
